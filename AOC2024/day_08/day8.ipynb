# %%
f = open("demo8.txt", "r")
for line in f:
    line=line.replace("\n", "")
    print(line)
f.close()
# Out:
# ..........
#
# ..........
#
# ..........
#
# ....a.....
#
# ..........
#
# .....a....
#
# ..........
#
# ..........
#
# ..........
#
# ..........
